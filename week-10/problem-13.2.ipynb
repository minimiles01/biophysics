# %% [markdown]
# # 13.2 RELAXATION OSCILLATOR
#
# Use this notebook to store your work for this problem.

# %% [markdown]
# ## (a) Mechanical Oscillator
#
# Create a phase portrait and streamlines for the mechanical oscillator.  (This is similar to Problem 13.1, but include nullclines this time.)  Discuss the qualitative behavior of the system.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def f1(var, t):
    return [var[1] / np.cos(var[0]), -var[0] / np.sqrt(1 + (var[0] ** 2))]

theta, dm = np.meshgrid(np.linspace(-np.pi/2, np.pi/2, 20), np.linspace(-1, 1, 20))

dmprime = f1([theta, dm], 0)

for i in [0.1,0.5,0.9]:
    path = odeint(f1, [0.0,i], np.linspace(0, 50, 200))
    plt.plot(path[:,0], path[:,1], 'b-')

null1 = np.linspace(-5,5,20)
plt.plot(null1, nullx * 0, 'y-')

null2 = odeint(f1, [0.0,0.5], np.linspace(0, 50, 200))
plt.plot(null2[:,0], null2[:,1], 'y-')
    
plt.quiver(theta, dm, dmprime[0], dmprime[1], color = 'r')
plt.xlim([-np.pi, np.pi])
plt.ylim([-2, 2])
plt.show()

# %% [markdown]
# ## (b) Relaxation Oscillator
#
# Create a phase portrait — plus nullclines and streamlines — for the relaxation oscillator.

# %% [markdown]
# ***Replace with your comments.***
